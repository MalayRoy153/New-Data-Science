# %%
import pandas as pd

# %%
df = pd.read_csv('house price.csv')

# %% [markdown]
# DATA PREPROCESSING

# %%
df
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df = df.drop(columns=['street', 'city',
       'statezip', 'country','date'])

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated'],
#       dtype='object')

# %%
df = df[(df['sqft_basement'] != 0) & (df['yr_renovated'] != 0)]

# %%
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 4     5.500000e+05         4       2.50         1940     10500     1.0
# 11    1.400000e+06         4       2.50         2920      4000     1.5
# 24    4.950000e+05         4       1.75         1600      6380     1.0
# 29    7.900000e+05         3       2.50         2600      4750     1.0
# 31    4.999500e+05         4       2.50         2860      3345     2.0
# ...            ...       ...        ...          ...       ...     ...
# 4566  5.586538e+05         3       2.50         1530      3210     1.5
# 4572  1.288333e+06         6       4.50         3830      4800     3.0
# 4579  4.547900e+05         2       1.75         1990      4000     1.0
# 4583  2.827667e+05         4       2.00         1700      8640     1.0
# 4589  1.828050e+05         3       1.00         1040      8892     1.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 818 entries, 4 to 4589
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          818 non-null    float64
#  1   bedrooms       818 non-null    int64
#  2   bathrooms      818 non-null    float64
#  3   sqft_living    818 non-null    int64
#  4   sqft_lot       818 non-null    int64
#  5   floors         818 non-null    float64
#  6   waterfront     818 non-null    int64
#  7   view           818 non-null    int64
#  8   condition      818 non-null    int64
#  9   sqft_above     818 non-null    int64
#  10  sqft_basement  818 non-null    int64
#  11  yr_built       818 non-null    int64
#  12  yr_renovated   818 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 89.5 KB

# %% [markdown]
# DATA SPLITING

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['price'], axis=1)
y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_df = X_train.join(y_train)

# %%
train_df
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 1198         4       1.75         2260      7005     1.0           0     1
# 822          3       2.00         1020      1204     2.0           0     0
# 2342         3       1.75         2430     14607     1.0           0     1
# 3150         3       1.00         1830      8004     1.0           0     0
# 4211         2       1.00         1320      8830     1.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 1439         4       2.75         3040      2800     2.0           0     0
# 2952         4       2.00         2200      7700     1.0           0     0
# 396          3       3.00         2480     45302     1.0           0     0
# 1006         4       1.50         2500      6300     1.0           0     0
# 1659         3       1.75         1790     12000     1.0           0     0
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Chceking relation between the datas

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_df.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# LINEAR REGRESSOR

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_s= scaler.fit_transform(X_train)
X_test_s = scaler.transform(X_test)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train_s,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_s)

# %%
#To get R**2 score between 0 and 1 , closer to 1 , the better the value

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.7771426687826473

# %%
#To get RMSE AND MSE AND RMAE AND MAE   /// Lower the values better the prediction model

# %%
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.metrics import mean_squared_error

# %%
# Mean Squared Error

# %%
MSE = mean_squared_error(y_test, y_pred)
MSE
# Out:
# 54558940531.98669

# %%
# Root Mean Squared Error

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 233578.55323635062

# %%
#Mean Absolute Error

# %%
MAE = mean_absolute_error(y_test, y_pred)
MAE
# Out:
# 162658.5710828848

# %%
#Root Mean Absolute Error

# %%
RMAE = np.sqrt(MAE)
RMAE
# Out:
# 403.30952267815945

# %% [markdown]
# RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=300, criterion='friedman_mse', random_state=42)
rf.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor(criterion='friedman_mse', n_estimators=300,
#                       random_state=42)

# %%
rfy_pred = rf.predict(X_test_s)

# %%
#To get R**2 score between 0 and 1 , closer to 1 , the better the value
r2 = r2_score(y_test, rfy_pred)
r2
# Out:
# 0.7273972113758986

# %%
# Mean Squared Error
MSEs = mean_squared_error(y_test, rfy_pred)
MSEs
# Out:
# 66737402140.432724

# %%
# Root Mean Squared Error
RMSEs = np.sqrt(MSEs)
RMSEs
# Out:
# 258335.83208767753

# %%
#Mean Absolute Error
MAEs = mean_absolute_error(y_test, rfy_pred)
MAEs
# Out:
# 167834.906229313

# %%
# Root Mean Absolute Error
RMAEs = np.sqrt(MAEs)
RMAEs
# Out:
# 409.6765873580195

# %%
# THE END

# %%
# The Random Forest Regressor performed worse than the Linear Regressor, don't know the reason and som features like street , city have not been utilized, I'll try to use them next time
